# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !nvidia-smi
# Out:
# Wed Mar 24 16:38:52 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !unzip /content/drive/MyDrive/Colab\ Notebooks/Projects/TensorFlow/Todo/CNN/Weather-Classification/data.zip
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/Projects/TensorFlow/Todo/CNN/Weather-Classification/data.zip
# replace Multi-class Weather Dataset/Cloudy/cloudy1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
directory = "/content/drive/MyDrive/Colab Notebooks/Projects/TensorFlow/Todo/CNN/Weather-Classification"
data = '/content/Multi-class Weather Dataset'

# %%
# !pip3 install wandb

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import wandb
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras.activations import *
from tensorflow.keras.layers import *
from tensorflow.keras.losses import BinaryCrossentropy,SparseCategoricalCrossentropy,CategoricalCrossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from wandb.keras import *
import random
import os

# %%
class_names = os.listdir(data)

# %%
class_names
# Out:
# ['Shine', 'Cloudy', 'Rain', 'Sunrise']

# %%
# train_datagen = ImageDataGenerator(rescale=1/255.0,validation_split=0.25)
# train_data = train_datagen.flow_from_directory(data)
# valid_data = train_datagen.flow_from_directory(data,subset='validation')

# %%
# len(train_data)

# %%
# len(valid_data)

# %%
import matplotlib.image as mpimg

# %%
# Become one with the data
how_many_imgs = int(input('How Many Img"s ? \n '))
for _ in range(how_many_imgs):
  random_class = random.choice(class_names)
  random_file = random.choice(os.listdir(data + f'/{random_class}/'))
  img = mpimg.imread(data + f'/{random_class}/{random_file}')
  plt.figure(figsize=(10,7))
  plt.imshow(img)
  plt.axis(False)
  plt.title(f'random_file : {random_file} | random_class : {random_class} | img.shape : {img.shape}')
  plt.show();
# Out:
# How Many Img"s ?
#  5

# %%
train_datagen = ImageDataGenerator(rescale=1/255.0,width_shift_range=0.25,height_shift_range=0.25,zoom_range=0.25,horizontal_flip=True,vertical_flip=True,validation_split=0.25)

# %%
train_data = train_datagen.flow_from_directory(data,target_size=(224,224),subset='training')
test_data = train_datagen.flow_from_directory(data,target_size=(224,224),subset='validation')
# Out:
# Found 845 images belonging to 4 classes.
# Found 280 images belonging to 4 classes.

# %% [markdown]
# #### Modellling

# %%
project_name = 'weather-prediction'

# %%
# wandb.init(project='weather-prediction',name='baseline')
# baseline_model = tf.keras.Sequential([
#   Conv2D(10,3,activation=relu,input_shape=(224,224,3)),
#   MaxPool2D(),
#   Conv2D(10,3,activation=relu),
#   MaxPool2D(),
#   Conv2D(10,3,activation=relu),
#   MaxPool2D(),
#   Flatten(),
#   Dense(len(class_names),activation=softmax)
# ])
# baseline_model.compile(loss=CategoricalCrossentropy(),metrics=['accuracy'],optimizer=SGD())
# baseline_model.fit(train_data,validation_data=(test_data),epochs=25,callbacks=[WandbCallback()])

# %%
# Epochs
# Activations
# Optimizer
# lr
# layers
# filters
# kernal size

# %%
# Epochs

# %%
# wandb.init(project='weather-prediction',name='100-epoch-test')
# model = tf.keras.Sequential([
#   Conv2D(10,3,activation=relu,input_shape=(224,224,3)),
#   MaxPool2D(),
#   Conv2D(10,3,activation=relu),
#   MaxPool2D(),
#   Conv2D(10,3,activation=relu),
#   MaxPool2D(),
#   Flatten(),
#   Dense(len(class_names),activation=softmax)
# ])
# model.compile(loss=CategoricalCrossentropy(),metrics=['accuracy'],optimizer=SGD())
# model.fit(train_data,validation_data=(test_data),epochs=100,callbacks=[WandbCallback()])

# %%
# Activations

# %%
# activations = [relu,elu,selu,tanh,exponential]
# for activation in activations:
#   wandb.init(project='weather-prediction',name=f'{activation}-activation-test')
#   model = tf.keras.Sequential([
#     Conv2D(10,3,activation=activation,input_shape=(224,224,3)),
#     MaxPool2D(),
#     Conv2D(10,3,activation=activation),
#     MaxPool2D(),
#     Conv2D(10,3,activation=activation),
#     MaxPool2D(),
#     Flatten(),
#     Dense(len(class_names),activation=softmax)
#   ])
#   model.compile(loss=CategoricalCrossentropy(),metrics=['accuracy'],optimizer=SGD())
#   model.fit(train_data,validation_data=(test_data),epochs=25,callbacks=[WandbCallback()])

# %%
# Optimizer

# %%
# optimizers = [Adam(),SGD()]
# for optimizer in optimizers:
#   wandb.init(project='weather-prediction',name=f'{optimizer}-optimizer-test')
#   model = tf.keras.Sequential([
#     Conv2D(10,3,activation=relu,input_shape=(224,224,3)),
#     MaxPool2D(),
#     Conv2D(10,3,activation=relu),
#     MaxPool2D(),
#     Conv2D(10,3,activation=relu),
#     MaxPool2D(),
#     Flatten(),
#     Dense(len(class_names),activation=softmax)
#   ])
#   model.compile(loss=CategoricalCrossentropy(),metrics=['accuracy'],optimizer=optimizer)
#   model.fit(train_data,validation_data=(test_data),epochs=25,callbacks=[WandbCallback()])

# %%
# filters

# %%
# filters = [round(12.5),25,50]
# for filter in filters:
#   wandb.init(project='weather-prediction',name=f'{filters}-filter-test')
#   model = tf.keras.Sequential([
#     Conv2D(filter,3,activation=relu,input_shape=(224,224,3)),
#     MaxPool2D(),
#     Conv2D(filter,3,activation=relu),
#     MaxPool2D(),
#     Conv2D(filter,3,activation=relu),
#     MaxPool2D(),
#     Flatten(),
#     Dense(len(class_names),activation=softmax)
#   ])
#   model.compile(loss=CategoricalCrossentropy(),metrics=['accuracy'],optimizer=SGD())
#   model.fit(train_data,validation_data=(test_data),epochs=25,callbacks=[WandbCallback()])

# %%
# kernals

# %%
# kernals = [5,10,round(12.5)]
# for kernal in kernals:
#   wandb.init(project='weather-prediction',name=f'{kernal}-kernal-test')
#   model = tf.keras.Sequential([
#     Conv2D(10,kernal,activation=relu,input_shape=(224,224,3)),
#     MaxPool2D(),
#     Conv2D(10,kernal,activation=relu),
#     MaxPool2D(),
#     Conv2D(10,kernal,activation=relu),
#     MaxPool2D(),
#     Flatten(),
#     Dense(len(class_names),activation=softmax)
#   ])
#   model.compile(loss=CategoricalCrossentropy(),metrics=['accuracy'],optimizer=SGD())
#   model.fit(train_data,validation_data=(test_data),epochs=25,callbacks=[WandbCallback()])

# %%
## Results
### Epochs = 175 (With EarlyStopping)
### Activations = elu
### Optimizer = Adam
### lr = 0.001
### layers = 10
### filters = 50
### kernal size = 3

# %%
# wandb.init(project='weather-prediction',name=f'Big-Dog-Model-1')
# model = tf.keras.Sequential([
#   Conv2D(50,3,activation=elu,input_shape=(224,224,3)),
#   MaxPool2D(),
#   Conv2D(50,3,activation=elu),
#   MaxPool2D(),
#   Conv2D(50,3,activation=elu),
#   MaxPool2D(),
#   Flatten(),
#   Dense(len(class_names),activation=softmax)
# ])
# model.compile(loss=CategoricalCrossentropy(),metrics=['accuracy'],optimizer=Adam(0.001))
# model.fit(train_data,validation_data=(test_data),epochs=175,callbacks=[WandbCallback(),EarlyStopping(patience=7)])
# model.save(directory + '/model_4.h5')

# %%
model = tf.keras.models.load_model(directory + '/model_1.h5')

# %%
class_names
# Out:
# ['Shine', 'Cloudy', 'Rain', 'Sunrise']

# %%
imgs_test = os.listdir('test/')

# %%
imgs_test
# Out:
# ['images (9).jpeg',
#  'download (11).jpeg',
#  'download (6).jpeg',
#  'images (8).jpeg',
#  'download (9).jpeg',
#  'download (7).jpeg',
#  'download (12).jpeg',
#  'download (10).jpeg']

# %%
for img in imgs_test:
  img = tf.io.read_file(f'test/{img}')
  img = tf.image.decode_jpeg(img)
  img = tf.image.resize(img,(224,224))
  img = img / 255.0
  result = model.predict(tf.expand_dims(img,axis=0))
  plt.figure(figsize=(10,7))
  plt.imshow(img)
  plt.axis(False)
  plt.title(f'Result : {class_names[result.argmax()]}')
  plt.show();
